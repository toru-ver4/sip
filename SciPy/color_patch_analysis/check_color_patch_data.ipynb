# %% [markdown]
# # このファイルの目的
# 本解析とは別にデータの確認などをする

# %% [markdown]
# # Color Patch の Spectral Data 確認

# %%
# %matplotlib inline
import check_color_patch_data as ccpd
import imp
imp.reload(ccpd)
ccpd.show_color_patch_spectral_data()

# %% [markdown]
# # Color Patch を無理やりプロットしてみる
#
# ## 概要
# color patch の xyY データは [ここ](http://www.poynton.com/notes/color/GretagMacbeth-ColorChecker.html) で公開されているので、以下の手順で sRGB色域の RGB値を求める。
#
# 1. xyY to XYZ 変換
# 2. XYZ to RGB 変換
#
# ## xyY to XYZ 変換
#
# xyz の導出式より以下のことが成り立つ。
#
# \begin{align}
# y &= \frac{Y}{X + Y + Z} \\
# \frac{Y}{y} &= X + Y + Z \\
# \end{align}
#
# ここで x について変形して以下を得る。
# \begin{align}
# x &= \frac{X}{X + Y + Z} \\
# X &= x(X + Y + Z) \\
# X &= x \cdot \frac{Y}{y}
# \end{align}
#
# 同様に z についても求めると以下が得られる。Y は xyY の値をそのまま使う。
#
# \begin{align}
# X &= x \cdot \frac{Y}{y} \\
# Z &= z \cdot \frac{Y}{y} \\
# \end{align}
#
# ## XYZ to RGB 変換
# 以前に SciPy の検証で作ったモジュールがあるのでそれを流用する。
# ただし、この行列は RGB値が 0～1 に正規化されている前提なので先程求めた XYZ値も良い感じに正規化しておく。
#
# ## プロット結果
# 以下に示す。なんか白がピンクっぽいんですが、こんなもんですかね…

# %%
# %matplotlib inline
import check_color_patch_data as ccpd
import imp
imp.reload(ccpd)
ccpd.make_color_patch_image()
# Out:
# Caution! Overflow has occured.
